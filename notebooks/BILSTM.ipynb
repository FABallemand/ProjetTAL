# %%
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler

import spacy
# Out:
# 2023-05-04 13:16:10.597266: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-04 13:16:10.599853: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-04 13:16:10.648947: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-04 13:16:10.649557: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 13:16:11.393316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !python3 -m spacy download fr_core_news_sm
spacy.load('fr_core_news_sm')

# %%
nlp = spacy.load("fr_core_news_sm")
from nltk.corpus import stopwords
from nltk import download
download('stopwords')
stopWords = set(stopwords.words('french'))
print(stopWords)
# Out:
# {'étais', 'soyez', 'soyons', 'son', 'te', 'nous', 'as', 'ayants', 'qui', 'ayant', 'avait', 'serions', 'étions', 'aviez', 'ayons', 'que', 'fusse', 'fut', 'ait', 't', 'étant', 'étantes', 'ou', 'nos', 'par', 'y', 'soient', 'tes', 'eussent', 'ne', 'fus', 'sur', 'seriez', 'étées', 'eussions', 'qu', 'aies', 'était', 'et', 'eut', 'ont', 'eûmes', 'eues', 'ton', 'le', 'ce', 'mes', 'eusses', 'ta', 'seront', 'étante', 'lui', 'es', 'sa', 'avais', 'notre', 'fussiez', 'du', 'étiez', 'eux', 'eu', 'aient', 'avions', 'une', 'eût', 'étés', 'l', 'vous', 'de', 'sommes', 'serait', 'ayantes', 'tu', 'sont', 'il', 'ces', 'c', 'ma', 'moi', 'serez', 'un', 'furent', 'des', 'auraient', 'on', 'avec', 'd', 'serai', 'soit', 'ai', 'eurent', 'êtes', 'vos', 'eusse', 'sera', 'est', 'avaient', 'aurez', 'à', 'm', 'avez', 'n', 'eus', 'aurai', 'se', 's', 'suis', 'fûmes', 'aurais', 'auras', 'ayante', 'aux', 'fussent', 'dans', 'fussions', 'aie', 'fusses', 'mais', 'toi', 'seras', 'aurions', 'ils', 'auriez', 'serons', 'eûtes', 'les', 'fût', 'aura', 'sois', 'j', 'aurait', 'avons', 'été', 'aurons', 'auront', 'eussiez', 'fûtes', 'étaient', 'ayez', 'leur', 'pas', 'serais', 'me', 'étants', 'seraient', 'en', 'pour', 'la', 'même', 'étée', 'eue', 'ses', 'au', 'je', 'elle', 'votre', 'mon'}
# [nltk_data] Downloading package stopwords to /home/el0h1m/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # BILSTM

# %% [markdown]
# ## Chargement des Données

# %%
# Données d'entrainement
train_data_complete = pd.read_csv("../data/allocine_genres_train.csv", sep=",")
train_data = train_data_complete[["titre", "synopsis", "genre"]]

# Données de test/validation
test_data_complete = pd.read_csv("../data/allocine_genres_test.csv", sep=",")
test_data = test_data_complete[["titre", "synopsis", "genre"]]

# %%
import string

def preprocess(sentence) :
    list_w = nlp(sentence)
    list_w_clean = []
    res = []
    for token in list_w:
        if (token.text.lower() not in stopWords) and (token.text not in string.punctuation):
            list_w_clean.append(token)
    for token in list_w_clean:
        res.append(token.lemma_.lower())
    return " ".join(res)

# %%
X = train_data.drop('genre', axis=1)
y = train_data['genre']

# Initialize the RandomOverSampler
ros = RandomOverSampler(random_state=42)
#ros = RandomUnderSampler(random_state=42)

X["titre"] = X["titre"].apply(preprocess)
X["synopsis"] = X["synopsis"].apply(preprocess)

# Perform oversampling
X_resampled, y_resampled = ros.fit_resample(X, y)

# Convert the resampled data back to a DataFrame
train_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='genre')], axis=1)

# %% [markdown]
# Lister les classes et leur associer un identifiant unique. (Utile pour le plongement des mots et pour l'entraînement du CNN).

# %%
# Liste des genres
genre_name = sorted(train_data.genre.unique().flatten())
print("Genres:", genre_name)
print("Nombre d'exemplaires:", len(train_data))

# Identifiant unique par genre
genre_index = {genre_name[i]:i for i in range(len(genre_name))}
genre_index
# Out:
# Genres: ['biopic', 'comédie', 'documentaire', 'drame', 'historique', 'horreur', 'policier', 'romance', 'science fiction']
# Nombre d'exemplaires: 4509
# {'biopic': 0,
#  'comédie': 1,
#  'documentaire': 2,
#  'drame': 3,
#  'historique': 4,
#  'horreur': 5,
#  'policier': 6,
#  'romance': 7,
#  'science fiction': 8}

# %% [markdown]
# Remplacer les genres par la valeur numérique associée.

# %%
train_data = train_data.replace({"genre": genre_index})
train_data.head()
# Out:
#                   titre                                           synopsis  \
# 0  crime orient express  visite istanbul célèbre détectiv belge hercule...
# 1       12 homme colère  jeune homme origine modeste accuser meurtre pè...
# 2         après bonheur  lorsque marie-laure mère quatre jeune enfant a...
# 3         lumière ville  vagabond ’ éprendre ’ belle jeune vendeur fleu...
# 4        chemin dignité  histoire vrai carl brashear premier afro améri...
#
#    genre
# 0      6
# 1      3
# 2      3
# 3      7
# 4      0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_data[["titre", "synopsis"]],
                                                    train_data[["genre"]],
                                                    test_size=0.001,
                                                    random_state=12, # Random seed for shuffle
                                                    shuffle=True)

# %% [markdown]
# On combine le titre et le synopsis pour pouvoir les vectoriser par la suite.

# %%
X_train_titre = X_train.titre
X_train = X_train_titre + " " + X_train.synopsis

# %%
X_train.head()
# Out:
# 841     mourir 20 an soudan province ’ aljazira jour p...
# 2949    tina histoire anna mae bullock promettre humbl...
# 868     fleur tonnerre 1800 bretagne genou accabler ré...
# 1284    prof 2 pire prof france débarquer angleterre m...
# 1267    char olivier autre histoire palestine histoire...
# dtype: object

# %%
y_train.head()
# Out:
#       genre
# 841       3
# 2949      0
# 868       3
# 1284      1
# 1267      2

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4504,)
# (4504, 1)

# %% [markdown]
# ## Indexation du Vocabulaire

# %%
def get_vectorizer(documents, max_voc_size=8000, max_seq_length= 200, batch_size=64):
	vectorizer = tf.keras.layers.TextVectorization(max_tokens=max_voc_size, output_sequence_length=max_seq_length)
	# Création du jeu de données à partir de X_train et constitution de lots de 128 instances
	text_ds = tf.data.Dataset.from_tensor_slices(documents).batch(batch_size)
	# Création du vocabulaire à partir des données d'entrée
	vectorizer.adapt(text_ds)
	return vectorizer

# %%
vectorizer = get_vectorizer(X_train)
# Out:
# 2023-05-04 13:17:00.464918: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [4504]
# 	 [[{{node Placeholder/_0}}]]

# %%
voc = vectorizer.get_vocabulary()
print(len(voc))
# Out:
# 8000

# %%
voc[:10]
# Out:
# ['', '[UNK]', '’', 'avoir', 'plus', 'tout', 'faire', 'aller', 'vie', 'jeune']

# %%
word_index = dict(zip(voc, range(len(voc))))

# %%
print("Texte initial:", X_train.iloc[1])
output = vectorizer([X_train.iloc[1]])
print("Vocabulaire dans le texte (15 premiers items):")
for v in output.numpy()[0, :15]:
    print(v, vectorizer.get_vocabulary()[v])
# Out:
# Texte initial: tina histoire anna mae bullock promettre humble carrièr infirmier après rencontre ike turner vie orageux aller devenir grand chanteur rock conner
# Vocabulaire dans le texte (15 premiers items):
# 1 [UNK]
# 23 histoire
# 861 anna
# 5329 mae
# 1 [UNK]
# 680 promettre
# 1 [UNK]
# 1 [UNK]
# 1519 infirmier
# 33 après
# 66 rencontre
# 1 [UNK]
# 6831 turner
# 8 vie
# 5260 orageux

# %% [markdown]
# ## Chargement de Plongements de Mots Pré-entraînés

# %%
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format("../embedding/frWiki_no_phrase_no_postag_700_cbow_cut100.bin", binary=True, unicode_errors="ignore")
model.most_similar("bonjour")
# Out:
# [('merci', 0.7507892847061157),
#  ('bonsoir', 0.7450243830680847),
#  ('votre', 0.5642200112342834),
#  ('vous', 0.5538792014122009),
#  ('remercier', 0.5396129488945007),
#  ('avance', 0.5288880467414856),
#  ('discuter', 0.5033395886421204),
#  ('je', 0.49339333176612854),
#  ('désoler', 0.4899965822696686),
#  ('ici', 0.4887441396713257)]

# %%
model.key_to_index
# Out:
# {'</s>': 0,
#  'de': 1,
#  'la': 2,
#  'à': 3,
#  'le': 4,
#  'et': 5,
#  'être': 6,
#  'en': 7,
#  'les': 8,
#  'un': 9,
#  'une': 10,
#  'avoir': 11,
#  'il': 12,
#  'dans': 13,
#  'par': 14,
#  'catégorie': 15,
#  'pour': 16,
#  'sur': 17,
#  'que': 18,
#  'se': 19,
#  'qui': 20,
#  'des': 21,
#  'ce': 22,
#  'avec': 23,
#  'ne': 24,
#  'son': 25,
#  'an': 26,
#  'plus': 27,
#  'ou': 28,
#  'pas': 29,
#  'faire': 30,
#  'elle': 31,
#  'sa': 32,
#  'pouvoir': 33,
#  'pop': 34,
#  'premier': 35,
#  'mais': 36,
#  'comme': 37,
#  'cette': 38,
#  'français': 39,
#  'avancement': 40,
#  'ses': 41,
#  'je': 42,
#  'on': 43,
#  'deux': 44,
#  'france': 45,
#  'tout': 46,
#  'aussi': 47,
#  'lien': 48,
#  'grand': 49,
#  'année': 50,
#  'autre': 51,
#  'naissance': 52,
#  'article': 53,
#  'nom': 54,
#  'après': 55,
#  'voir': 56,
#  'commune': 57,
#  'état': 58,
#  'ville': 59,
#  'externe': 60,
#  'y': 61,
#  'paris': 62,
#  'référence': 63,
#  'entre': 64,
#  'lui': 65,
#  'même': 66,
#  'source': 67,
#  'sous': 68,
#  'jean': 69,
#  'lieu': 70,
#  'leur': 71,
#  'site': 72,
#  'note': 73,
#  'où': 74,
#  'dont': 75,
#  'film': 76,
#  'ces': 77,
#  'groupe': 78,
#  'nouveau': 79,
#  'depuis': 80,
#  'décès': 81,
#  'titre': 82,
#  'ils': 83,
#  'date': 84,
#  'naître': 85,
#  'national': 86,
#  'équipe': 87,
#  'devenir': 88,
#  'situer': 89,
#  'devoir': 90,
#  'ancien': 91,
#  'partie': 92,
#  'mettre': 93,
#  'joueur': 94,
#  'américain': 95,
#  'très': 96,
#  'nord': 97,
#  'si': 98,
#  'pays': 99,
#  'monde': 100,
#  'page': 101,
#  'contre': 102,
#  'prendre': 103,
#  '&': 104,
#  'fin': 105,
#  'politique': 106,
#  'utiliser': 107,
#  'mort': 108,
#  'liste': 109,
#  'dernier': 110,
#  'dire': 111,
#  'saison': 112,
#  'sans': 113,
#  'série': 114,
#  'puis': 115,
#  'janvier': 116,
#  'trouver': 117,
#  'région': 118,
#  'image': 119,
#  'général': 120,
#  'plusieurs': 121,
#  'point': 122,
#  'pierre': 123,
#  'permettre': 124,
#  'certain': 125,
#  'jour': 126,
#  'club': 127,
#  'vers': 128,
#  'mars': 129,
#  'histoire': 130,
#  'mai': 131,
#  'population': 132,
#  'créer': 133,
#  'juin': 134,
#  'alors': 135,
#  'donner': 136,
#  'non': 137,
#  'homme': 138,
#  'famille': 139,
#  'temps': 140,
#  'place': 141,
#  'septembre': 142,
#  'ligne': 143,
#  'trois': 144,
#  'bien': 145,
#  'petit': 146,
#  'album': 147,
#  'juillet': 148,
#  'octobre': 149,
#  'aller': 150,
#  'avril': 151,
#  'membre': 152,
#  'début': 153,
#  'jeu': 154,
#  'connaître': 155,
#  'août': 156,
#  'donc': 157,
#  'décembre': 158,
#  'guerre': 159,
#  'novembre': 160,
#  'département': 161,
#  'me': 162,
#  'celle': 163,
#  'nombreux': 164,
#  'tour': 165,
#  'fois': 166,
#  'février': 167,
#  'meilleur': 168,
#  'heure': 169,
#  'passer': 170,
#  'principal': 171,
#  'seul': 172,
#  'sortir': 173,
#  'centre': 174,
#  'cour': 175,
#  'selon': 176,
#  'suivant': 177,
#  'église': 178,
#  "jusqu'à": 179,
#  'siècle': 180,
#  'ainsi': 181,
#  'louis': 182,
#  'vous': 183,
#  'nombre': 184,
#  'art': 185,
#  'football': 186,
#  'vie': 187,
#  'village': 188,
#  'pendant': 189,
#  'roi': 190,
#  'leurs': 191,
#  'connexe': 192,
#  'sud': 193,
#  'quelques': 194,
#  'celui': 195,
#  'jouer': 196,
#  'droit': 197,
#  'allemand': 198,
#  'espèce': 199,
#  'international': 200,
#  'réaliser': 201,
#  'langue': 202,
#  'lequel': 203,
#  'encore': 204,
#  'musique': 205,
#  'travail': 206,
#  'personne': 207,
#  'édition': 208,
#  'rester': 209,
#  'appeler': 210,
#  'suite': 211,
#  'historique': 212,
#  'championnat': 213,
#  'genre': 214,
#  'origine': 215,
#  'écrire': 216,
#  'femme': 217,
#  'public': 218,
#  'eau': 219,
#  'avant': 220,
#  'nommer': 221,
#  'président': 222,
#  'exemple': 223,
#  'château': 224,
#  'important': 225,
#  'officiel': 226,
#  'venir': 227,
#  'fils': 228,
#  'service': 229,
#  'rue': 230,
#  'projet': 231,
#  'publier': 232,
#  'porter': 233,
#  'mondial': 234,
#  'type': 235,
#  'but': 236,
#  'différent': 237,
#  'second': 238,
#  'europe': 239,
#  'épisode': 240,
#  'acteur': 241,
#  'chef': 242,
#  'forme': 243,
#  'charles': 244,
#  'or': 245,
#  'anglais': 246,
#  'cet': 247,
#  'auteur': 248,
#  'long': 249,
#  'présenter': 250,
#  'société': 251,
#  'bon': 252,
#  'olympique': 253,
#  'jeune': 254,
#  'division': 255,
#  'haut': 256,
#  'île': 257,
#  'paul': 258,
#  'système': 259,
#  'ordre': 260,
#  'roman': 261,
#  'télévision': 262,
#  'militaire': 263,
#  'obtenir': 264,
#  'fonction': 265,
#  'province': 266,
#  'prix': 267,
#  'étude': 268,
#  'rôle': 269,
#  'époque': 270,
#  'bar': 271,
#  'scène': 272,
#  'moyen': 273,
#  'bas': 274,
#  'texte': 275,
#  'durant': 276,
#  'quatre': 277,
#  'construire': 278,
#  'sport': 279,
#  'personnalité': 280,
#  'saint': 281,
#  'modèle': 282,
#  'participer': 283,
#  'tel': 284,
#  'rendre': 285,
#  'père': 286,
#  'chez': 287,
#  'carrière': 288,
#  'enfant': 289,
#  'deuxième': 290,
#  'cas': 291,
#  'final': 292,
#  'chaque': 293,
#  'suivre': 294,
#  'version': 295,
#  'numéro': 296,
#  'toujours': 297,
#  'marie': 298,
#  'jacques': 299,
#  'monument': 300,
#  'françois': 301,
#  'john': 302,
#  'ministre': 303,
#  'base': 304,
#  'italien': 305,
#  '+': 306,
#  'habitant': 307,
#  'comprendre': 308,
#  'savoir': 309,
#  'zone': 310,
#  'activité': 311,
#  'armée': 312,
#  'champion': 313,
#  'production': 314,
#  'maison': 315,
#  'falloir': 316,
#  'recevoir': 317,
#  'commencer': 318,
#  'ensemble': 319,
#  'actuel': 320,
#  'ouest': 321,
#  'représenter': 322,
#  'niveau': 323,
#  'exister': 324,
#  'cela': 325,
#  'école': 326,
#  'canton': 327,
#  'période': 328,
#  'elles': 329,
#  'remporter': 330,
#  'mois': 331,
#  'demander': 332,
#  'commun': 333,
#  'gouvernement': 334,
#  'car': 335,
#  'agir': 336,
#  'livre': 337,
#  'ensuite': 338,
#  'université': 339,
#  'composer': 340,
#  'nous': 341,
#  'former': 342,
#  'lier': 343,
#  'technique': 344,
#  'ça': 345,
#  'considérer': 346,
#  'chanson': 347,
#  'peu': 348,
#  'entreprise': 349,
#  'fille': 350,
#  "aujourd'hui": 351,
#  'européen': 352,
#  'création': 353,
#  'robert': 354,
#  'concerner': 355,
#  'cependant': 356,
#  'tard': 357,
#  'section': 358,
#  'côté': 359,
#  'michel': 360,
#  'argent': 361,
#  'sembler': 362,
#  'britannique': 363,
#  'italie': 364,
#  'fort': 365,
#  'souvent': 366,
#  'personnage': 367,
#  'moins': 368,
#  'question': 369,
#  'vouloir': 370,
#  'fichier': 371,
#  'wikipedia': 372,
#  'victoire': 373,
#  'fonder': 374,
#  'recensement': 375,
#  'force': 376,
#  'compter': 377,
#  'style': 378,
#  'retrouver': 379,
#  'quand': 380,
#  'original': 381,
#  'fait': 382,
#  'compétition': 383,
#  'précédent': 384,
#  'environ': 385,
#  'recherche': 386,
#  'siège': 387,
#  'kilomètre': 388,
#  'suisse': 389,
#  'allemagne': 390,
#  'produire': 391,
#  'latitude': 392,
#  'simple': 393,
#  'déjà': 394,
#  'route': 395,
#  'constituer': 396,
#  'noir': 397,
#  'problème': 398,
#  'longitude': 399,
#  'social': 400,
#  'construction': 401,
#  'territoire': 402,
#  'corps': 403,
#  'blanc': 404,
#  'position': 405,
#  'parti': 406,
#  'élection': 407,
#  'troisième': 408,
#  'reprendre': 409,
#  'maire': 410,
#  'proposer': 411,
#  'loi': 412,
#  'tête': 413,
#  'terre': 414,
#  'résultat': 415,
#  'vivre': 416,
#  'ceux': 417,
#  'tenir': 418,
#  'là': 419,
#  'servir': 420,
#  'terme': 421,
#  'canada': 422,
#  'rouge': 423,
#  'match': 424,
#  'bataille': 425,
#  'frère': 426,
#  'objet': 427,
#  'parler': 428,
#  'local': 429,
#  'dès': 430,
#  'couleur': 431,
#  'score': 432,
#  'soit': 433,
#  'plan': 434,
#  'york': 435,
#  'laisser': 436,
#  'royal': 437,
#  'député': 438,
#  'décider': 439,
#  'mer': 440,
#  'développer': 441,
#  'maître': 442,
#  'parmi': 443,
#  'arriver': 444,
#  'poste': 445,
#  'direction': 446,
#  'domaine': 447,
#  'ouvrir': 448,
#  'scientifique': 449,
#  'in': 450,
#  'arrondissement': 451,
#  'québec': 452,
#  'part': 453,
#  'perdre': 454,
#  'henri': 455,
#  'mouvement': 456,
#  'communauté': 457,
#  'posséder': 458,
#  'travailler': 459,
#  'top': 460,
#  'action': 461,
#  'âge': 462,
#  'pont': 463,
#  'apparaître': 464,
#  'supérieur': 465,
#  'écrivain': 466,
#  'information': 467,
#  'espagne': 468,
#  'science': 469,
#  'sujet': 470,
#  'été': 471,
#  'lancer': 472,
#  'désigner': 473,
#  'formation': 474,
#  'présent': 475,
#  'penser': 476,
#  'code': 477,
#  'libre': 478,
#  'développement': 479,
#  'atteindre': 480,
#  'cinq': 481,
#  'merci': 482,
#  'organiser': 483,
#  'voie': 484,
#  'pièce': 485,
#  'réseau': 486,
#  'quartier': 487,
#  'classement': 488,
#  'joseph': 489,
#  'david': 490,
#  'culture': 491,
#  'occuper': 492,
#  'gare': 493,
#  'bois': 494,
#  'discuter': 495,
#  'compte': 496,
#  'directeur': 497,
#  'mourir': 498,
#  'sortie': 499,
#  'ici': 500,
#  'remplacer': 501,
#  'chemin': 502,
#  'propre': 503,
#  'mère': 504,
#  'affaire': 505,
#  'mot': 506,
#  'vainqueur': 507,
#  'philippe': 508,
#  'mise': 509,
#  'beaucoup': 510,
#  'terminer': 511,
#  'élire': 512,
#  'bronze': 513,
#  'association': 514,
#  'peintre': 515,
#  'rejoindre': 516,
#  'gauche': 517,
#  'artiste': 518,
#  'surtout': 519,
#  'demande': 520,
#  'carte': 521,
#  'rencontrer': 522,
#  'lorsque': 523,
#  'ouvrage': 524,
#  'médaille': 525,
#  'professionnel': 526,
#  'découvrir': 527,
#  'marquer': 528,
#  'claude': 529,
#  'belge': 530,
#  'minute': 531,
#  'divers': 532,
#  'parfois': 533,
#  'durée': 534,
#  'retour': 535,
#  'classer': 536,
#  'musée': 537,
#  'installer': 538,
#  'milieu': 539,
#  'devant': 540,
#  'beau': 541,
#  'possible': 542,
#  'municipalité': 543,
#  'sélection': 544,
#  'lettre': 545,
#  'bâtiment': 546,
#  'prince': 547,
#  'succès': 548,
#  'superficie': 549,
#  'georges': 550,
#  'montrer': 551,
#  'théâtre': 552,
#  'mon': 553,
#  'diriger': 554,
#  'jamais': 555,
#  'central': 556,
#  'conseil': 557,
#  'double': 558,
#  'sou': 559,
#  'naturel': 560,
#  'afrique': 561,
#  'russe': 562,
#  'court': 563,
#  'martin': 564,
#  'élément': 565,
#  'cinéma': 566,
#  'espagnol': 567,
#  'espace': 568,
#  'van': 569,
#  'belgique': 570,
#  'san': 571,
#  'établir': 572,
#  'musical': 573,
#  'bande': 574,
#  'autres': 575,
#  'contenir': 576,
#  'sein': 577,
#  'parcours': 578,
#  'angleterre': 579,
#  'élever': 580,
#  'andré': 581,
#  'parc': 582,
#  'japonais': 583,
#  'voix': 584,
#  'étranger': 585,
#  'agglomération': 586,
#  'combat': 587,
#  'total': 588,
#  'aide': 589,
#  'rome': 590,
#  'effectuer': 591,
#  'valeur': 592,
#  'conserver': 593,
#  'critique': 594,
#  'duc': 595,
#  'sens': 596,
#  'discussion': 597,
#  'fer': 598,
#  'trop': 599,
#  'moment': 600,
#  'hockey': 601,
#  'eux': 602,
#  'mener': 603,
#  'jpg': 604,
#  'district': 605,
#  'inscrire': 606,
#  'amérique': 607,
#  'professeur': 608,
#  'ajouter': 609,
#  'comte': 610,
#  'coupe': 611,
#  'compagnie': 612,
#  'économique': 613,
#  'quitter': 614,
#  'idée': 615,
#  'administration': 616,
#  'japon': 617,
#  'port': 618,
#  'tableau': 619,
#  'honneur': 620,
#  'ni': 621,
#  'proche': 622,
#  'adresser': 623,
#  'million': 624,
#  'romain': 625,
#  'rapport': 626,
#  'revenir': 627,
#  'aucun': 628,
#  'religieux': 629,
#  'comté': 630,
#  'produit': 631,
#  'paraître': 632,
#  'chanteur': 633,
#  'relation': 634,
#  'conseiller': 635,
#  'main': 636,
#  'entraîneur': 637,
#  'organisation': 638,
#  'transport': 639,
#  'croix': 640,
#  'cadre': 641,
#  'station': 642,
#  'émission': 643,
#  'ami': 644,
#  'publication': 645,
#  'unité': 646,
#  'taille': 647,
#  'enfin': 648,
#  'étape': 649,
#  'vue': 650,
#  'communal': 651,
#  'réalisateur': 652,
#  'glace': 653,
#  'manière': 654,
#  'moi': 655,
#  'rien': 656,
#  'appartenir': 657,
#  'assurer': 658,
#  'sportif': 659,
#  'indiquer': 660,
#  'droite': 661,
#  'partir': 662,
#  'six': 663,
#  'classe': 664,
#  'régional': 665,
#  'personnel': 666,
#  'raison': 667,
#  'arme': 668,
#  "jusqu'en": 669,
#  'canadien': 670,
#  'londres': 671,
#  'assez': 672,
#  'signer': 673,
#  'mètre': 674,
#  'malgré': 675,
#  'intérieur': 676,
#  'évêque': 677,
#  'tuer': 678,
#  'charger': 679,
#  'placer': 680,
#  'tourner': 681,
#  'entrer': 682,
#  'course': 683,
#  'fiche': 684,
#  'collection': 685,
#  'salle': 686,
#  'journal': 687,
#  'également': 688,
#  'continuer': 689,
#  'coup': 690,
#  'programme': 691,
#  'porte': 692,
#  'étudiant': 693,
#  'diffusion': 694,
#  'mission': 695,
#  'populaire': 696,
#  'passage': 697,
#  'rivière': 698,
#  'ball': 699,
#  'dérouler': 700,
#  'consacrer': 701,
#  'richard': 702,
#  'james': 703,
#  'semaine': 704,
#  'dix': 705,
#  'civil': 706,
#  'campagne': 707,
#  '°': 708,
#  'mesure': 709,
#  'demi': 710,
#  'choisir': 711,
#  'web': 712,
#  'évolution': 713,
#  'envoyer': 714,
#  'plupart': 715,
#  'william': 716,
#  'féminin': 717,
#  'lire': 718,
#  'évoluer': 719,
#  'effet': 720,
#  'annoncer': 721,
#  'humain': 722,
#  'compositeur': 723,
#  'priver': 724,
#  'stade': 725,
#  'thomas': 726,
#  'urbain': 727,
#  'troupe': 728,
#  'reconnaître': 729,
#  'classique': 730,
#  'vitesse': 731,
#  'russie': 732,
#  'loire': 733,
#  'façon': 734,
#  'diffuser': 735,
#  'george': 736,
#  'gagner': 737,
#  'situation': 738,
#  'ma': 739,
#  'téléviser': 740,
#  'single': 741,
#  'disposer': 742,
#  'dater': 743,
#  'catholique': 744,
#  'subdivision': 745,
#  'grec': 746,
#  'royaume': 747,
#  'producteur': 748,
#  'abord': 749,
#  'bretagne': 750,
#  'dessus': 751,
#  'décision': 752,
#  'navire': 753,
#  'célèbre': 754,
#  'issir': 755,
#  'qualité': 756,
#  'michael': 757,
#  'tenter': 758,
#  'majeur': 759,
#  'engager': 760,
#  'nicolas': 761,
#  'vol': 762,
#  'battre': 763,
#  'lac': 764,
#  'actif': 765,
#  'entrée': 766,
#  'footballeur': 767,
#  'inconnu': 768,
#  'utilisation': 769,
#  'air': 770,
#  'bernard': 771,
#  'nature': 772,
#  'présence': 773,
#  'docteur': 774,
#  'chose': 775,
#  'moteur': 776,
#  'opération': 777,
#  'ailleurs': 778,
#  'régiment': 779,
#  'réalisation': 780,
#  'toutefois': 781,
#  'arrêter': 782,
#  'chine': 783,
#  'hiver': 784,
#  'offrir': 785,
#  'chaîne': 786,
#  'culturel': 787,
#  'mal': 788,
#  'mode': 789,
#  'photo': 790,
#  'scénario': 791,
#  'moderne': 792,
#  'changer': 793,
#  'occasion': 794,
#  'officier': 795,
#  'chercher': 796,
#  'mont': 797,
#  'enregistrer': 798,
#  'lyon': 799,
#  'toute': 800,
#  'portail': 801,
#  'attaque': 802,
#  'dessiner': 803,
#  'condition': 804,
#  'statut': 805,
#  'intérêt': 806,
#  'poser': 807,
#  'particulier': 808,
#  'principe': 809,
#  'finir': 810,
#  'déclarer': 811,
#  'terrain': 812,
#  'expliquer': 813,
#  'montagne': 814,
#  'animal': 815,
#  "lorsqu'": 816,
#  'chapelle': 817,
#  'localité': 818,
#  'protéger': 819,
#  'peuple': 820,
#  'donnée': 821,
#  'structure': 822,
#  'presse': 823,
#  'latin': 824,
#  'intituler': 825,
#  'citer': 826,
#  'baser': 827,
#  'chacun': 828,
#  'utilisateur': 829,
#  'tomber': 830,
#  'opposer': 831,
#  'vieux': 832,
#  'associer': 833,
#  'amour': 834,
#  'pied': 835,
#  'décrire': 836,
#  'vendre': 837,
#  'chinois': 838,
#  'valoir': 839,
#  'élève': 840,
#  'aucune': 841,
#  'australie': 842,
#  'montréal': 843,
#  'sept': 844,
#  'courant': 845,
#  'départ': 846,
#  'caractère': 847,
#  'tirer': 848,
#  'étudier': 849,
#  'marc': 850,
#  'interne': 851,
#  'anne': 852,
#  'conflit': 853,
#  'éditeur': 854,
#  'vert': 855,
#  'rugby': 856,
#  'intégrer': 857,
#  'traduction': 858,
#  'nuit': 859,
#  'mandat': 860,
#  'capitale': 861,
#  'large': 862,
#  'répondre': 863,
#  'usage': 864,
#  'règle': 865,
#  'vidéo': 866,
#  'mieux': 867,
#  'exposition': 868,
#  'marine': 869,
#  'charge': 870,
#  'avis': 871,
#  'administratif': 872,
#  'détruire': 873,
#  'maurice': 874,
#  'croire': 875,
#  'empereur': 876,
#  'volume': 877,
#  'format': 878,
#  'tournoi': 879,
#  'surface': 880,
#  'seine': 881,
#  'municipal': 882,
#  'marché': 883,
#  'supprimer': 884,
#  'pratique': 885,
#  'influence': 886,
#  'altitude': 887,
#  'imposer': 888,
#  'soutenir': 889,
#  'logo': 890,
#  'antoine': 891,
#  'accepter': 892,
#  'qualifier': 893,
#  'label': 894,
#  'abbaye': 895,
#  'propriétaire': 896,
#  'avion': 897,
#  'étendre': 898,
#  'débuter': 899,
#  'forêt': 900,
#  'prévoir': 901,
#  'littérature': 902,
#  'épreuve': 903,
#  'journaliste': 904,
#  'vallée': 905,
#  'refuser': 906,
#  'disparaître': 907,
#  'secteur': 908,
#  'modifier': 909,
#  'chrétien': 910,
#  'for': 911,
#  'contrôle': 912,
#  'unique': 913,
#  'juste': 914,
#  'bruxelles': 915,
#  'seigneur': 916,
#  'définir': 917,
#  'accueillir': 918,
#  'table': 919,
#  'décéder': 920,
#  'conduire': 921,
#  'regrouper': 922,
#  'complet': 923,
#  'choix': 924,
#  'théorie': 925,
#  'parvenir': 926,
#  'autorité': 927,
#  'acte': 928,
#  'côte': 929,
#  'record': 930,
#  'rencontre': 931,
#  'revue': 932,
#  'taire': 933,
#  'guillaume': 934,
#  'daniel': 935,
#  'traverser': 936,
#  'patrimoine': 937,
#  'file': 938,
#  'border': 939,
#  'automobile': 940,
#  'architecture': 941,
#  'réponse': 942,
#  'comporter': 943,
#  'feu': 944,
#  'albert': 945,
#  'quel': 946,
#  'accompagner': 947,
#  'traduire': 948,
#  'méthode': 949,
#  'limiter': 950,
#  'épouser': 951,
#  'peter': 952,
#  'architecte': 953,
#  'aimer': 954,
#  'futur': 955,
#  'physique': 956,
#  'noter': 957,
#  'phase': 958,
#  'poursuivre': 959,
#  'essai': 960,
#  'commercial': 961,
#  'disputer': 962,
#  'besoin': 963,
#  'destiner': 964,
#  'pologne': 965,
#  'propriété': 966,
#  'radio': 967,
#  'extérieur': 968,
#  'aider': 969,
#  'nécessaire': 970,
#  'bleu': 971,
#  'alexandre': 972,
#  'piste': 973,
#  'train': 974,
#  'industriel': 975,
#  'frontière': 976,
#  'votre': 977,
#  'attendre': 978,
#  'inclure': 979,
#  'majorité': 980,
#  'contributeur': 981,
#  'photographie': 982,
#  'cheval': 983,
#  'sécurité': 984,
#  'taux': 985,
#  'fondateur': 986,
#  'longueur': 987,
#  'message': 988,
#  'peinture': 989,
#  'alpes': 990,
#  'énergie': 991,
#  'inspirer': 992,
#  'dessin': 993,
#        -2.33267117e-02,  7.05864966e-01, -6.05441630e-01,  3.39937836e-01,
#         1.45732284e-01,  7.25149512e-02, -1.98078141e-01, -8.02953064e-01,
#        -1.29950726e-02, -5.47135949e-01,  5.94918132e-01, -2.23544776e-01,
#         4.13303256e-01,  4.71579820e-01,  6.69899106e-01,  5.97547650e-01,
#         2.05604345e-01, -6.64332867e-01,  3.80126238e-01, -6.18129130e-03,
#         2.90732712e-01, -1.20666623e-01, -9.72738922e-01,  1.39240324e-01,
#         2.36141294e-01, -6.26896977e-01,  1.70403540e-01,  1.73117667e-01,
#         1.12495683e-01,  8.32356066e-02, -3.34135741e-01,  3.80744636e-01,
#        -2.59999424e-01,  1.29647923e+00,  3.40001643e-01,  2.19689339e-01,
#         8.82253230e-01,  1.12707846e-01, -6.36712015e-01, -4.17713702e-01,
#         6.07774258e-01, -5.27768970e-01, -7.08885550e-01, -7.24545836e-01,
#         4.63197738e-01, -6.76877379e-01, -5.44933736e-01, -1.99850738e-01,
#         8.97430778e-01,  4.92413826e-02,  1.50183171e-01,  4.69598800e-01,
#         2.07603216e-01, -4.73009825e-01, -1.00822163e+00, -4.40766215e-02,
#         1.51380628e-01, -2.17882261e-01, -2.23561630e-01,  7.55998313e-01,
#         4.36851263e-01, -3.33539546e-01, -3.90896797e-02,  3.17714691e-01,
#        -3.78571332e-01, -3.67802143e-01, -7.00299442e-02, -7.48388246e-02,
#        -1.41743168e-01, -1.72362328e-01, -3.07423353e-01,  2.98040897e-01,
#         2.46473968e-01,  1.32397830e-01,  1.04720104e+00,  3.58292073e-01,
#         1.03869125e-01,  4.75986421e-01, -2.60389745e-01, -7.86486268e-03,
#         5.99572897e-01,  3.60617757e-01, -1.08815260e-01, -1.22736394e+00,
#         3.81040543e-01,  2.20555037e-01,  5.87766647e-01, -6.71569169e-01,
#         1.45082867e+00, -7.78131112e-02, -9.48488772e-01,  3.48283857e-01,
#         4.90349412e-01,  4.14216518e-01,  6.45747900e-01, -3.07553083e-01,
#        -3.29392821e-01, -3.31324875e-01, -1.35984376e-01,  3.71608406e-01,
#         8.51248264e-01, -4.11335558e-01, -4.83015895e-01, -2.07950592e-01,
#         1.49750531e-01,  3.68860960e-01,  4.75695163e-01, -1.17586267e+00,
#         2.81834565e-02,  5.72014488e-02,  3.51272225e-01, -2.51247615e-01,
#         7.99956679e-01, -1.93470642e-01, -3.30183208e-01, -6.98590934e-01,
#         3.42658848e-01, -5.70239663e-01,  3.12321689e-02,  3.46526802e-01],
#       dtype=float32)

# %% [markdown]
# Le plongement pré-entrainé est de dimension 700.

# %%
len(model["bonjour"])
# Out:
# 700

# %%
def load_embeddings(embeddings_model):
    embeddings_index = {}
    for word in list(embeddings_model.key_to_index.keys()):
        embeddings_index[word] = embeddings_model[word]
    print(f'{len(embeddings_index)} vecteurs de mots ont été lus')
    return embeddings_index

# %%
embeddings = load_embeddings(model)
# Out:
# 39392 vecteurs de mots ont été lus

# %% [markdown]
# La cellule suivante permet de créer une matrice de plongements: une matrice où la ligne i correspond au plongement pré-entraîné pour le mot d'indice i dans le vocabulaire.

# %%
def get_embedding_matrix(vocabulary, embeddings_index, embedding_dim = 700):
  num_tokens = len(vocabulary)
  hits = 0
  misses = 0

  # Préparation de la matrice
  # Les mots qui ne se trouvent pas dans les plongements pré-entraînés seront 
  # représentés par des vecteurs dont toutes les composantes sont égales à 0,
  # y compris la représentation utilisée pour compléter les documents courts et
  # celle utilisée pour les mots inconnus [UNK]
  embedding_matrix = np.zeros((num_tokens, embedding_dim))
  for word, i in word_index.items():
      embedding_vector = embeddings_index.get(word)
      if embedding_vector is not None:
          embedding_matrix[i] = embedding_vector
          hits += 1
      else:
          misses += 1
  print(f'{hits} mots ont été trouvés dans les plongements pré-entraînés')
  print(f'{misses} sont absents')
  return embedding_matrix

# %%
# Construction de la matrice de plongements à partir du vocabulaire
embedding_matrix = get_embedding_matrix(voc, embeddings)
# Out:
# 6068 mots ont été trouvés dans les plongements pré-entraînés
# 1932 sont absents

# %% [markdown]
# ## Construction du LSTM

# %%
from tensorflow.keras.layers import Embedding

def get_biLSTM_model(voc_size, embedding_matrix, embedding_dim=700):
  # Création du modèle
  int_sequences_input = tf.keras.Input(shape=(None,), dtype="int64")
  embedding_layer = Embedding(voc_size, embedding_dim, trainable=True,
      embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
  )
  
  embedded_sequences = embedding_layer(int_sequences_input)
  x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, dropout=0.2, recurrent_dropout=0.2))(embedded_sequences)
  preds = tf.keras.layers.Dense(len(genre_name), activation="softmax")(x)
  model = tf.keras.Model(int_sequences_input, preds)
  return model

# %%
# Affichage de l'architecture du modèle
biLSTM_model = get_biLSTM_model(len(voc), embedding_matrix)
biLSTM_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 700)         5600000
#
#  bidirectional (Bidirectiona  (None, 128)              391680
#  l)
#
#  dense (Dense)               (None, 9)                 1161
#
# =================================================================
# Total params: 5,992,841
# Trainable params: 5,992,841
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entraînement du LSTM

# %%
from sklearn import model_selection
from tensorflow.keras.callbacks import EarlyStopping # Early stopping to avoid over-fitting

# Fonction pour l'entraînement d'un modèle
def train_model(X, y, model_function, vectorizer, voc_size, embedding_matrix, embedding_dim=700, batch_size=64): # 128
    
    # Early stopping callback
    early_stopping_callback = EarlyStopping(monitor="val_acc", restore_best_weights=True, patience=3)
    
    # Listes utilisées pour sauvegarder les résultats obtenus à chaque pli
    acc_per_fold = []
    loss_per_fold = []
    histories = []
    folds = 5
    stratkfold = model_selection.StratifiedKFold(n_splits=folds, shuffle=True, random_state=12)
    fold_no = 1
    for train, test in stratkfold.split(X, y):
        m_function = globals()[model_function]
        model = m_function(voc_size, embedding_matrix, embedding_dim)

        print('------------------------------------------------------------------------')
        print(f'Entraînement pour le pli {fold_no} ...')
        fold_x_train = vectorizer(X.iloc[train].to_numpy()).numpy()
        fold_x_val = vectorizer(X.iloc[test].to_numpy()).numpy()
        fold_y_train = y.iloc[train].to_numpy()
        fold_y_val = y.iloc[test].to_numpy()

        # Compilation du modèle : permet de préciser la fonction de perte et l'optimiseur
        # loss=sparse_categorical_crossentropy : entropie croisée, dans le cas où les 
        # classes cibles sont indiquées sous forme d'entiers. Il s'agira de minimiser
        # la perte pendant l'apprentissage
        # optimizer=rmsprop : l'optimiseur détermine la manière doit les poids seront
        # mis à jour pendant l'apprentissage
        model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["acc"])
        # Entraînement sur 10 époque (la totalité du jeu de données est parcourue
        # 10 fois)
        history = model.fit(fold_x_train, fold_y_train, batch_size=batch_size, epochs=25, validation_data=(fold_x_val, fold_y_val), callbacks=[early_stopping_callback])
        histories.append(history)
        # Evaluation sur les données de validation
        scores = model.evaluate(fold_x_val, fold_y_val, verbose=0)
        print(f'Scores pour le pli {fold_no}: {model.metrics_names[0]} = {scores[0]:.2f};',
            f'{model.metrics_names[1]} = {scores[1]*100:.2f}%')
        acc_per_fold.append(scores[1] * 100)
        loss_per_fold.append(scores[0])
        fold_no = fold_no + 1

    # Affichage des scores moyens par pli
    print('---------------------------------------------------------------------')
    print('Scores par pli')
    for i in range(0, len(acc_per_fold)):
        print('---------------------------------------------------------------------')
        print(f'> Pli {i+1} - Loss: {loss_per_fold[i]:.2f}', f'- Accuracy: {acc_per_fold[i]:.2f}%')
    print('---------------------------------------------------------------------')
    print('Scores moyens pour tous les plis :')
    print(f'> Accuracy: {np.mean(acc_per_fold):.2f}', f'(+- {np.std(acc_per_fold):.2f})')
    print(f'> Loss: {np.mean(loss_per_fold):.2f}')
    print('---------------------------------------------------------------------')
    return histories

# %%
# Entraînement du modèle et récupération des résultats
biLSTM_histories = train_model(X_train, y_train, 'get_biLSTM_model', vectorizer, len(voc), embedding_matrix)
# Out:
# ------------------------------------------------------------------------
# Entraînement pour le pli 1 ...
# Epoch 1/25
# 57/57 [==============================] - 33s 540ms/step - loss: 1.9065 - acc: 0.3708 - val_loss: 1.5142 - val_acc: 0.5194
# Epoch 2/25
# 57/57 [==============================] - 31s 546ms/step - loss: 1.2567 - acc: 0.6181 - val_loss: 1.2230 - val_acc: 0.5794
# Epoch 3/25
# 57/57 [==============================] - 31s 546ms/step - loss: 0.9026 - acc: 0.7250 - val_loss: 1.1025 - val_acc: 0.6404
# Epoch 4/25
# 57/57 [==============================] - 31s 549ms/step - loss: 0.6729 - acc: 0.7963 - val_loss: 0.9735 - val_acc: 0.6870
# Epoch 5/25
# 57/57 [==============================] - 31s 544ms/step - loss: 0.5254 - acc: 0.8465 - val_loss: 1.0097 - val_acc: 0.6837
# Epoch 6/25
# 57/57 [==============================] - 31s 546ms/step - loss: 0.4083 - acc: 0.8804 - val_loss: 0.8463 - val_acc: 0.7270
# Epoch 7/25
# 57/57 [==============================] - 34s 601ms/step - loss: 0.3019 - acc: 0.9145 - val_loss: 0.8850 - val_acc: 0.7270
# Epoch 8/25
# 57/57 [==============================] - 32s 560ms/step - loss: 0.2378 - acc: 0.9281 - val_loss: 0.8990 - val_acc: 0.7303
# Epoch 9/25
# 57/57 [==============================] - 32s 561ms/step - loss: 0.1833 - acc: 0.9487 - val_loss: 0.8764 - val_acc: 0.7547
# Epoch 10/25
# 57/57 [==============================] - 32s 560ms/step - loss: 0.1469 - acc: 0.9650 - val_loss: 1.1435 - val_acc: 0.7170
# Epoch 11/25
# 57/57 [==============================] - 32s 559ms/step - loss: 0.1152 - acc: 0.9697 - val_loss: 0.9294 - val_acc: 0.7514
# Epoch 12/25
# 57/57 [==============================] - 32s 559ms/step - loss: 0.0836 - acc: 0.9822 - val_loss: 0.9311 - val_acc: 0.7647
# Epoch 13/25
# 57/57 [==============================] - 32s 560ms/step - loss: 0.0646 - acc: 0.9872 - val_loss: 1.1511 - val_acc: 0.7414
# Epoch 14/25
# 57/57 [==============================] - 32s 561ms/step - loss: 0
25
# 57/57 [==============================] - 32s 565ms/step - loss: 0.3724 - acc: 0.8857 - val_loss: 0.9285 - val_acc: 0.7300
# Epoch 7/25
# 57/57 [==============================] - 32s 564ms/step - loss: 0.2881 - acc: 0.9148 - val_loss: 0.9274 - val_acc: 0.7278
# Epoch 8/25
# 57/57 [==============================] - 32s 563ms/step - loss: 0.2054 - acc: 0.9453 - val_loss: 0.9215 - val_acc: 0.7389
# Epoch 9/25
# 57/57 [==============================] - 32s 565ms/step - loss: 0.1720 - acc: 0.9537 - val_loss: 0.9195 - val_acc: 0.7622
# Epoch 10/25
# 57/57 [==============================] - 32s 565ms/step - loss: 0.1315 - acc: 0.9659 - val_loss: 0.8924 - val_acc: 0.7644
# Epoch 11/25
# 57/57 [==============================] - 32s 565ms/step - loss: 0.0989 - acc: 0.9770 - val_loss: 1.0694 - val_acc: 0.7378
# Epoch 12/25
# 57/57 [==============================] - 32s 565ms/step - loss: 0.0697 - acc: 0.9847 - val_loss: 1.1404 - val_acc: 0.7378
# Epoch 13/25
# 57/57 [==============================] - 32s 565ms/step - loss: 0.0678 - acc: 0.9845 - val_loss: 1.0426 - val_acc: 0.7678
# Epoch 14/25
# 57/57 [==============================] - 32s 563ms/step - loss: 0.0484 - acc: 0.9903 - val_loss: 1.1179 - val_acc: 0.7600
# Epoch 15/25
# 57/57 [==============================] - 33s 578ms/step - loss: 0.0435 - acc: 0.9903 - val_loss: 1.0888 - val_acc: 0.7689
# Epoch 16/25
# 57/57 [==============================] - 33s 583ms/step - loss: 0.0397 - acc: 0.9925 - val_loss: 1.1735 - val_acc: 0.7644
# Epoch 17/25
# 57/57 [==============================] - 33s 579ms/step - loss: 0.0265 - acc: 0.9953 - val_loss: 1.1564 - val_acc: 0.7678
# Epoch 18/25
# 57/57 [==============================] - 33s 578ms/step - loss: 0.0257 - acc: 0.9942 - val_loss: 1.2412 - val_acc: 0.7567
# Scores pour le pli 5: loss = 1.09; acc = 76.89%
# ---------------------------------------------------------------------
# Scores par pli
# ---------------------------------------------------------------------
# > Pli 1 - Loss: 1.05 - Accuracy: 77.36%
# ---------------------------------------------------------------------
# > Pli 2 - Loss: 0.79 - Accuracy: 75.47%
# ---------------------------------------------------------------------
# > Pli 3 - Loss: 0.82 - Accuracy: 72.81%
# ---------------------------------------------------------------------
# > Pli 4 - Loss: 0.78 - Accuracy: 80.47%
# ---------------------------------------------------------------------
# > Pli 5 - Loss: 1.09 - Accuracy: 76.89%
# ---------------------------------------------------------------------
# Scores moyens pour tous les plis :
# > Accuracy: 76.60 (+- 2.50)
# > Loss: 0.91
# ---------------------------------------------------------------------

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

def plot_results(histories):
    accuracy_data = []
    loss_data = []
    for i, h in enumerate(histories):
        acc = h.history['acc']
        val_acc = h.history['val_acc']
        loss = h.history['loss']
        val_loss = h.history['val_loss']
        for j in range(len(acc)):
            accuracy_data.append([i+1, j+1, acc[j], 'Entraînement'])
            accuracy_data.append([i+1, j+1, val_acc[j], 'Validation'])
            loss_data.append([i+1, j+1, loss[j], 'Entraînement'])
            loss_data.append([i+1, j+1, val_loss[j], 'Validation'])

    acc_df = pd.DataFrame(accuracy_data, columns=['Pli', 'Epoch', 'Accuracy', 'Données'])
    sns.relplot(data=acc_df, x='Epoch', y='Accuracy', hue='Pli', style='Données', kind='line')
    
    loss_df = pd.DataFrame(loss_data, columns=['Pli', 'Epoch', 'Perte', 'Données'])
    sns.relplot(data=loss_df, x='Epoch', y='Perte', hue='Pli', style='Données', kind='line')

# %%
plot_results(biLSTM_histories)
